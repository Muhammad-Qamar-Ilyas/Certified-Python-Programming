# %%
"""
Question1:

Use a dictionary to store information about a person you know. Store their first name, last name, age,
and the city in which they live. You should have keys such as first_name, last_name, age, and city. Print
each piece of information stored in your dictionary. Add a new key value pair about qualification then
update the qualification value to high academic level then delete it. """

print("\nHello to the data record app\n")
record = {"first name" : "1" , "last name" : "1" , "age" : " 1" , "city" : "1"}
for rec_key in record.keys():
    record[rec_key] = input("Please enter " +rec_key+ " : ")
print("\n")
for rec_key,rec_value in record.items():
    print("The person's "+rec_key+" is ",rec_value)

decision = input("\nWould you like to add qualification of the person too? Y/N")
options = ("Y","y","Yes","YES","yes","Yeah","yeah","YEAH","YOO","yoo") 
if decision in options:     
    user_input = input("\nEnter key and value separated by commas (,): ")
    key, value = user_input.split(",")
    record[key]= value
    print("\nRecord updated\n")
    for rec_key,rec_value in record.items():
        print("The person's "+rec_key+" is ",rec_value)
    print("\nDamn! This nigga's academic level is high and our HOMIES will feel inferior ... Gotta delete his qualification\nNow the updated record is :\n")
    del record[key]
    for rec_key,rec_value in record.items():
        print("The person's "+rec_key+" is ",rec_value)
else:
    print("\nThank you soo much for your time")
# Out:
# Hello to the data record app
#
# Please enter first name : Muhammad Qamar
# Please enter last name : Ilyas Ansari Ashrafi
# Please enter age : 24
# Please enter city : Karachi
#
#
# The person's first name is  Muhammad Qamar
# The person's last name is  Ilyas Ansari Ashrafi
# The person's age is  24
# The person's city is  Karachi
#
# Would you like to add qualification of the person too? Y/NYOO
#
# Enter key and value separated by commas (,): Qualification,High academic level
#
# Record updated
#
# The person's first name is  Muhammad Qamar
# The person's last name is  Ilyas Ansari Ashrafi
# The person's age is  24
# The person's city is  Karachi
# The person's Qualification is  High academic level
#
# Damn! This nigga's academic level is high and our HOMIES will feel inferior ... Gotta delete his qualification
# Now the updated record is :
#
# The person's first name is  Muhammad Qamar
# The person's last name is  Ilyas Ansari Ashrafi
# The person's age is  24
# ...

# %%
"""
Question2:
Make a dictionary called cities. Use the names of three cities as keys in your dictionary. Create a
dictionary of information about each city and include the country that the city is in, its approximate
population, and one fact about that city. The keys for each city’s dictionary should be something like
country, population, and fact. Print the name of each city and all of the information you have stored
about it.
"""
Cities = {"Karachi":"","Mumbai":"","New York":""}
Information = {"Karachi": {"country" : "Pakistan","population":"14.91 Million","fact":"It is the Sixth largest city in the world by city population."},
              "Mumbai":{"country" : "India","population":"18.41 Million","fact":"Every day in Mumbai, more than 200 trains make over 2,000 trips along 300 kilometres of track, carrying more passengers per kilometre than any railway on earth."},
              "New York":{"country" : "United States","population":"8.623 Million","fact":"New York City is made up of five boroughs: Manhattan, The Bronx, Queens, Brooklyn, and Staten Island."}}
for x in Cities.keys():
    Cities[x] = Information[x]
required = input("Please enter required city information : ")
print("\n")
if required in Cities.keys():
    for key,value in Cities[required].items():
        print("The city's {} is {}".format(key,value))
else:
    print("\nCity Information does not exist")"""
Question3:
A movie theater charges different ticket prices depending on a person’s age. If a person is under the age
of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the
ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie
ticket.
"""

print("Welcome! Make sure you have a relaxed and chilling evening\n")
print("Under 3 = Free Tickets (WOOHOO)   Ages between 3 to 12 = $10 per ticket   Ages over 12 = $15 per ticket\n")
tickets= int(input("How many tickets would you like to have? : "))
print("Since it is a ticket generating machine, you will be asked for age of person for each ticket.\n")
for x in tickets:
    ages = int(input("Please enter the age : "))
    Total = 0
    if ages<3:
        print("Free ticket")
    elif (ages>=3 and ages<=9):
        print("$12 for ",ages)
        Total = Total + 12
    elif ages>12:
        print("$15 for ",ages)
        Total = Total + 15
    else:
        print("Please enter right age")
print("\nYour total bill for tickets is : {} \nENJOY THE MOVIE!".format(Total))
# Out:
# Please enter required city information : Mumbai
#
#
# The city's country is India
# The city's population is 18.41 Million
# The city's fact is Every day in Mumbai, more than 200 trains make over 2,000 trips along 300 kilometres of track, carrying more passengers per kilometre than any railway on earth.

# %%
"""
Question3:
A movie theater charges different ticket prices depending on a person’s age. If a person is under the age
of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the
ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie
ticket.
"""

print("Welcome! Make sure you have a relaxed and chilling evening\n")
print("Under 3 = Free Tickets (WOOHOO)   Ages between 3 to 12 = $10 per ticket   Ages over 12 = $15 per ticket\n")
tickets= int(input("How many tickets would you like to have? : "))
print("\nSince it is a ticket generating machine, you will be asked for age of person for each ticket.\n")
Total = 0
for x in range(tickets):
    ages = int(input("Please enter the age : "))
    if ages<3:
        print("Free ticket")
    elif (ages>=3 and ages<=9):
        print("$12 for ",ages)
        Total = Total + 12
    elif ages>9:
        print("$15 for ",ages)
        Total = Total + 15
    else:
        print("Please enter right age")
print("\nYour total bill for tickets is : ${} \nENJOY THE MOVIE!".format(Total))
# Out:
# Welcome! Make sure you have a relaxed and chilling evening
#
# Under 3 = Free Tickets (WOOHOO)   Ages between 3 to 12 = $10 per ticket   Ages over 12 = $15 per ticket
#
# How many tickets would you like to have? : 7
#
# Since it is a ticket generating machine, you will be asked for age of person for each ticket.
#
# Please enter the age : 4
# $12 for  4
# Please enter the age : 2
# Free ticket
# Please enter the age : 8
# $12 for  8
# Please enter the age : 9
# $12 for  9
# Please enter the age : 30
# $15 for  30
# Please enter the age : 35
# $15 for  35
# Please enter the age : 100
# $15 for  100
#
# Your total bill for tickets is : $81
# ENJOY THE MOVIE!

# %%
"""
Question4:
Write a function called favorite_book() that accepts one parameter, title. The function should print a
message, such as One of my favorite books is Alice in Wonderland. Call the function, making sure to
include a book title as an argument in the function call.
"""

def book_name(name): 
    print("\nOne of my favorite books is ",name)

user = input("Please enter your favourite book name to write it as a QOUTE :  ")

book_name(user)
# Out:
# Please enter your favourite book name to write it as a QOUTE :  Quantum Mechanics
#
# One of my favorite books is  Quantum Mechanics

# %%
"""
Question5:
Guess the number game
Write a program which randomly generate a number between 1 to 30 and ask the user in input field to
guess the correct number. Give three chances to user guess the number and also give hint to user if
hidden number is greater or smaller than the number he given to input field.
"""

print("GUESS GAME\nGuess a number between 1 to 30 and give your answer")
decision = input("\nAre you ready? : ")
options = ("Y","y","Yes","YES","yes","Yeah","yeah","YEAH","YOO","yoo") 
if decision in options:     
    number = random.randint(1,30)
    for x in range(3):
        user = int(input("\nPlease guess the number : "))
        if user<number:
            print("Guessed number is smaller!")
        elif user>number:
            print("Guessed number is greater!")
        elif x>3:
            print("YOU LOSE")
            break
        else:
            print("YES!! YOU GUESSED IT RIGHT")
            break
    if user==number:
        print("\nYOU WIN!")
    else:
        print("\nYOU LOSE")
else:
    print("\nHave a good day")
# Out:
# GUESS GAME
# Guess a number between 1 to 30 and give your answer
#
# Are you ready? : YOO
#
# Please guess the number : 16
# Guessed number is greater!
#
# Please guess the number : 4
# Guessed number is greater!
#
# Please guess the number : 2
# YES!! YOU GUESSED IT RIGHT
#
# YOU WIN!
